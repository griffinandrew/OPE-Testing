# %%
try:
    from IPython.core.display import HTML, Markdown, TextDisplayObject, Javascript
except ImportError:
    raise ImportError("from IPython.core.display import HTML, Markdown, TextDisplayObject, Javascript failed")

# %%
try: 
    from IPython.display import display, IFrame, Image
except ImportError:
    raise ImportError("from IPython.display import display, IFrame, Image failed")

# %%
try: 
    import ipywidgets as widgets
except ImportError:
    raise ImportError("import ipywidgets as widgets failed")

# %%
try:
    from ipywidgets import interact, fixed, Layout
except ImportError:
    raise ImportError("from ipywidgets import interact, fixed layout failed")

# %%
try:
    import os, requests, pty, re, subprocess, struct, sys, fcntl, termios, select
except ImportError:
    raise ImportError("import os, requests, pty, re, subprocess, struct, sys, fcntl, termios, select failed")

# %%
try: 
    from notebook.notebookapp import list_running_servers
except ImportError:
    raise ImportError("from notebook.notebookapp import list_running_servers failed")

# %%
try:
    import matplotlib
except ImportError:
    raise ImportError("import matplotlib failed")

# %%
try:
    import matplotlib.pyplot as plt
except ImportError:
    raise ImportError("import matplotlib.pyplot as plt failed")

# %%
try:
    from matplotlib import animation
except ImportError:
    raise ImportError("from matplotlib import animation failed")

# %%
try:
    import numpy as np
except ImportError:
    raise ImportError("import numpy as np failed")

# %%
try:
    import pandas as pd
except ImportError:
    raise ImportError("import pandas as pd failed")

# %%
try:
    import time
except ImportError:
    raise ImportError("import time failed")

# %%
try:
    import array
except ImportError:
    raise ImportError("import array failed")

# %%
try:
    import array
except ImportError:
    raise ImportError("import array failed")

# %%
try:
    import nbstripout
except ImportError:
    raise ImportError("import nbstripout failed")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 2
#       1 try:
# ----> 2     import nbstripout
#       3 except ImportError:
#
# ModuleNotFoundError: No module named 'nbstripout'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 4
#       2     import nbstripout
#       3 except ImportError:
# ----> 4     raise ImportError("import nbstripout failed")
#
# ImportError: import nbstripout failed

# %%
try:
    # !pip install jupyter-book
except ImportError:
    raise ImportError("!pip install jupyter-book jupyter-book failed")

# %%
try:
    # !pip install ghp-import
except ImportError:
    raise ImportError("import ghp-import failed")

# %%
try:
    import jupytext
except ImportError:
    raise ImportError("import jupytext failed")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 2
#       1 try:
# ----> 2     import jupytext
#       3 except ImportError:
#
# ModuleNotFoundError: No module named 'jupytext'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[18], line 4
#       2     import jupytext
#       3 except ImportError:
# ----> 4     raise ImportError("import jupytext failed")
#
# ImportError: import jupytext failed

# %%
try:
    import widgetsnbextension 
except ImportError:
    raise ImportError("import widgetsnbextension failed")

# %%
try:
    import jupyter_contrib_nbextensions
except ImportError:
    raise ImportError("import jupyter_contrib_nbextensions failed")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 2
#       1 try:
# ----> 2     import jupyter_contrib_nbextensions
#       3 except ImportError:
#
# ModuleNotFoundError: No module named 'jupyter_contrib_nbextensions'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[20], line 4
#       2     import jupyter_contrib_nbextensions
#       3 except ImportError:
# ----> 4     raise ImportError("import jupyter_contrib_nbextensions failed")
#
# ImportError: import jupyter_contrib_nbextensions failed

# %%
try:
    import ipydrawio 
except ImportError:
    raise ImportError("import ipydrawio failed")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 2
#       1 try:
# ----> 2     import ipydrawio
#       3 except ImportError:
#
# ModuleNotFoundError: No module named 'ipydrawio'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 4
#       2     import ipydrawio
#       3 except ImportError:
# ----> 4     raise ImportError("import ipydrawio failed")
#
# ImportError: import ipydrawio failed

# %%
try:
    # !pip install ipydrawio-export 
except ImportError:
    raise ImportError("import ipydrawio-export failed")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 26.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.8/257.8 kB 18.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.7/58.7 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 5.6 MB/s eta 0:00:00
# ...

# %%
try:
    # !pip install jupyterlab-myst
except ImportError:
    raise ImportError("import jupyterlab-myst failed")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 20.5 MB/s eta 0:00:00a 0:00:01
# ...

# %%
try:
    # !pip install jupyterlab-spellchecker
except ImportError:
    raise ImportError("import jupyterlab-spellchecker failed")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 23.2 MB/s eta 0:00:0000:0100:01
# ...

# %%
try:
    import nbconvert
except ImportError:
    raise ImportError("import nbconvert failed")
